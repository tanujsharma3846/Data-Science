# %% [markdown]
# ## Data Science Masters - Hindi - 19 Feb 2023

# %% [markdown]
# #### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# - Flask is a micro web framework written in Python that provides a simple and easy way to build web applications.
# #
# - Advantages of Flask
#     - Lightweight
#         - Flask is designed to be a lightweight and simple to use framework for building web applications.
#     - Ease to use
#         -It provides a minimal set of tools to get started quickly, making it a great choice for small projects or for developers who want to get up and running quickly.
#     - Easy to learn
#         -  Flask is a micro framework that has a simpler and more straightforward design compared to full-stack frameworks that makes it easier to learn and use for beginners.

# %% [markdown]
# #### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
# Flask application to display 'Hello World!!'

# <-- CODE -->

from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "Hello World!!"

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.9:5000
# Press CTRL+C to quit

# %% [markdown]
# ![Screenshot_244.png](attachment:Screenshot_244.png)

# %% [markdown]
# #### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# - The process of defining the URLs that map to specific functions or methods in your application.
# - We use app routes to determine which function or method should handle the request and return the response when a user visits a URL in our application

# %% [markdown]
# #### Q4.  Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# #### Company Name: ABC Corporation
# #### Location: India
# #### Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def details():
    return '''Company Name: ABC Corporation
                Location: India
                Contact Detail: 999-999-9999
    '''

@app.route("/welcome")
def welcome():
    return "Welcome to ABC Corporation"

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.200.224:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [21/Feb/2023 12:28:50] "GET /welcome HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2023 12:28:53] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ![Screenshot_246.png](attachment:Screenshot_246.png)![Screenshot_245.png](attachment:Screenshot_245.png)

# %% [markdown]
# #### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# - url_for() function is used in Flask for URL binding.
# - The first argument is the name of the specified function, and then we can pass any number of keyword argument corresponding to the variable part of the URL.

# %%
from flask import *

app = Flask(__name__)

@app.route("/hello")
def hello():
    return "Hello World!!"

@app.route("/hello1")
def hello1():
    return "Hello World_1!!"


@app.route('/test/<name>')
def user(name):
    if name == 'hello':
        return redirect(url_for('hello'))
    if name == 'hello1':
        return redirect(url_for('hello1'))


if __name__ == "__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.9:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [21/Feb/2023 21:20:51] "GET /test/hello1 HTTP/1.1" 302 -
# 127.0.0.1 - - [21/Feb/2023 21:20:51] "GET /hello1 HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2023 21:20:52] "GET /test/hello1 HTTP/1.1" 302 -
# 127.0.0.1 - - [21/Feb/2023 21:20:52] "GET /hello1 HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2023 21:20:55] "GET /test/hello HTTP/1.1" 302 -
# 127.0.0.1 - - [21/Feb/2023 21:20:55] "GET /hello HTTP/1.1" 200 -
